# %% [markdown]
# Os comandos abaixo carregam o famoso dataset do titanic no objeto chamado *df*. Explore a tabela e responda as seguintes questões **sempre colocando o código em Python utilizado para chegar às respostas.**
#
# 1) Quantas pessoas sobreviveram ao acidente?
# 2) Quantas criancas menores de 12 anos sobreviveram ao acidente?
# 3) Quantas pessoas embarcaram nos portos de Southampton OU Queenstow?
# 4) Crie um objeto chamado **passageiras** que seleciona somente as passageiras.
# 5) Crie um objeto chamado **criancas_cherbourg** que seleciona as crianças com menos de 12 anos E que embarcaram na cidade de Cherbourg.
# 6) Crie um objeto chamado **titanic_menor** e selecione as colunas de *nome*, *idade*, *classe* e *embarque*
# 7) Supondo que o valor da tarifa no dataset está em libras, e que 1£ = R$ 6.43, crie uma nova coluna chamada **tarifa_real** que contenha a tarifa de embarque em reais.
# 8) Agrupe pela coluna sobreviveu e calcule o número de passageiros por grupo (sim/nao)
# 9) Agrupe pelo local de embarque e calcule a média e a mediana da tarifa de cada grupo.
# 10) Agrupe pela classe e conte a quantidade de pessoas por classe
# 11) Agrupe pela classe e pela coluna sobreviveu e conte a quantidade de pessoas que sobreviveu de acordo com cada classe. Quem sobreviveu mais? A classe mais alta ou a mais baixa?
# 12) Agrupe pelo sexo e pela coluna sobreviveu e conte a quantidade de pessoas que sobreviveram de acordo com o sexo. Quem sobreviveu mais? Homens ou mulheres?

# %%
import pandas as pd

# %%
df = pd.read_csv('../dados/titanic.csv')
df
# Out:
#      id_passageiro sobreviveu  classe  \
# 0                1        nao       3
# 1                2        sim       1
# 2                3        sim       3
# 3                4        sim       1
# 4                5        nao       3
# ..             ...        ...     ...
# 886            887        nao       2
# 887            888        sim       1
# 888            889        nao       3
# 889            890        sim       1
# 890            891        nao       3
#
#                                                   nome       sexo  idade  \
# 0                              Braund, Mr. Owen Harris  masculino   22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...   feminino   38.0
# 2                               Heikkinen, Miss. Laina   feminino   26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)   feminino   35.0
# 4                             Allen, Mr. William Henry  masculino   35.0
# ..                                                 ...        ...    ...
# 886                              Montvila, Rev. Juozas  masculino   27.0
# 887                       Graham, Miss. Margaret Edith   feminino   19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"   feminino    NaN
# 889                              Behr, Mr. Karl Howell  masculino   26.0
# 890                                Dooley, Mr. Patrick  masculino   32.0
#
#      irmaos_conjuge  pais_criancas          passagem     tarifa cabine  \
# 0                 1              0         A/5 21171     7.2500    NaN
# 1                 1              0          PC 17599    71.2833    C85
# 2                 0              0  STON/O2. 3101282  7925.0000    NaN
# 3                 1              0            113803    53.1000   C123
# 4                 0              0            373450     8.0500    NaN
# ..              ...            ...               ...        ...    ...
# 886               0              0            211536    13.0000    NaN
# 887               0              0            112053    30.0000    B42
# 888               1              2        W./C. 6607    23.4500    NaN
# 889               0              0            111369    30.0000   C148
# 890               0              0            370376     7.7500    NaN
#
#         embarque
# 0    Southampton
# 1      Cherbourg
# 2    Southampton
# 3    Southampton
# 4    Southampton
# ..           ...
# 886  Southampton
# 887  Southampton
# 888  Southampton
# 889    Cherbourg
# 890    Queenstow
#
# [891 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id_passageiro   891 non-null    int64
#  1   sobreviveu      891 non-null    object
#  2   classe          891 non-null    int64
#  3   nome            891 non-null    object
#  4   sexo            891 non-null    object
#  5   idade           714 non-null    float64
#  6   irmaos_conjuge  891 non-null    int64
#  7   pais_criancas   891 non-null    int64
#  8   passagem        891 non-null    object
#  9   tarifa          891 non-null    float64
#  10  cabine          204 non-null    object
#  11  embarque        889 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 83.7+ KB

# %%
#questão 1)
df.loc[df['sobreviveu'] == 'sim']
len(df.loc[df['sobreviveu'] == 'sim'])
#R: 342 pessoas sobreviveram.
# Out:
# 342

# %%
# questão 2)
df.loc[(df['idade'] < 12) & (df['sobreviveu'] == 'sim' )]
len(df.loc[(df['idade'] < 12) & (df['sobreviveu'] == 'sim' )])
#R: 39 crianças menores de 12 anos sobreviveram ao acidente.
# Out:
# 39

# %%
#questão 3)
df.loc[(df['embarque'] == 'Southampton') | (df['embarque'] == 'Cherbourg')]
len(df.loc[(df['embarque'] == 'Southampton') | (df['embarque'] == 'Cherbourg')])
#R: 812 pessoas embarcaram em Southampton ou Cherbourg.
# Out:
# 812

# %%
#questão 4)
passageiras = df.loc[df['sexo'] == 'feminino']
passageiras.head()
# Out:
#    id_passageiro sobreviveu  classe  \
# 1              2        sim       1
# 2              3        sim       3
# 3              4        sim       1
# 8              9        sim       3
# 9             10        sim       2
#
#                                                 nome      sexo  idade  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  feminino   38.0
# 2                             Heikkinen, Miss. Laina  feminino   26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  feminino   35.0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  feminino   27.0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  feminino   14.0
#
#    irmaos_conjuge  pais_criancas          passagem     tarifa cabine  \
# 1               1              0          PC 17599    71.2833    C85
# 2               0              0  STON/O2. 3101282  7925.0000    NaN
# 3               1              0            113803    53.1000   C123
# 8               0              2            347742    11.1333    NaN
# 9               1              0            237736    30.0708    NaN
#
#       embarque
# 1    Cherbourg
# 2  Southampton
# 3  Southampton
# 8  Southampton
# 9    Cherbourg

# %%
# questão 5)
criancas_cherbourg = df.loc[(df['idade'] < 12) & (df['embarque'] == 'Cherbourg')]
criancas_cherbourg.head()
# Out:
#      id_passageiro sobreviveu  classe  \
# 43              44        sim       2
# 381            382        sim       3
# 448            449        sim       3
# 469            470        sim       3
# 644            645        sim       3
#
#                                          nome      sexo  idade  \
# 43   Laroche, Miss. Simonne Marie Anne Andree  feminino   3.00
# 381               Nakid, Miss. Maria ("Mary")  feminino   1.00
# 448            Baclini, Miss. Marie Catherine  feminino   5.00
# 469             Baclini, Miss. Helene Barbara  feminino   0.75
# 644                    Baclini, Miss. Eugenie  feminino   0.75
#
#      irmaos_conjuge  pais_criancas       passagem   tarifa cabine   embarque
# 43                1              2  SC/Paris 2123  41.5792    NaN  Cherbourg
# 381               0              2           2653  15.7417    NaN  Cherbourg
# 448               2              1           2666  19.2583    NaN  Cherbourg
# 469               2              1           2666  19.2583    NaN  Cherbourg
# 644               2              1           2666  19.2583    NaN  Cherbourg

# %%
#questão 6)
titanic_menor = df[['nome', 'idade', 'classe', 'embarque']]
titanic_menor.head()
# Out:
#                                                 nome  idade  classe  \
# 0                            Braund, Mr. Owen Harris   22.0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   38.0       1
# 2                             Heikkinen, Miss. Laina   26.0       3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   35.0       1
# 4                           Allen, Mr. William Henry   35.0       3
#
#       embarque
# 0  Southampton
# 1    Cherbourg
# 2  Southampton
# 3  Southampton
# 4  Southampton

# %%
# questão 7)
df['tarifa_real'] = df['tarifa']*6.43
df.head()
# Out:
#    id_passageiro sobreviveu  classe  \
# 0              1        nao       3
# 1              2        sim       1
# 2              3        sim       3
# 3              4        sim       1
# 4              5        nao       3
#
#                                                 nome       sexo  idade  \
# 0                            Braund, Mr. Owen Harris  masculino   22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   feminino   38.0
# 2                             Heikkinen, Miss. Laina   feminino   26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   feminino   35.0
# 4                           Allen, Mr. William Henry  masculino   35.0
#
#    irmaos_conjuge  pais_criancas          passagem     tarifa cabine  \
# 0               1              0         A/5 21171     7.2500    NaN
# 1               1              0          PC 17599    71.2833    C85
# 2               0              0  STON/O2. 3101282  7925.0000    NaN
# 3               1              0            113803    53.1000   C123
# 4               0              0            373450     8.0500    NaN
#
#       embarque   tarifa_real
# 0  Southampton     46.617500
# 1    Cherbourg    458.351619
# 2  Southampton  50957.750000
# 3  Southampton    341.433000
# 4  Southampton     51.761500

# %%
#questão 8)
df[['sobreviveu', 'id_passageiro']].groupby('sobreviveu')
df.head()
# Out:
#    id_passageiro sobreviveu  classe  \
# 0              1        nao       3
# 1              2        sim       1
# 2              3        sim       3
# 3              4        sim       1
# 4              5        nao       3
#
#                                                 nome       sexo  idade  \
# 0                            Braund, Mr. Owen Harris  masculino   22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   feminino   38.0
# 2                             Heikkinen, Miss. Laina   feminino   26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   feminino   35.0
# 4                           Allen, Mr. William Henry  masculino   35.0
#
#    irmaos_conjuge  pais_criancas          passagem     tarifa cabine  \
# 0               1              0         A/5 21171     7.2500    NaN
# 1               1              0          PC 17599    71.2833    C85
# 2               0              0  STON/O2. 3101282  7925.0000    NaN
# 3               1              0            113803    53.1000   C123
# 4               0              0            373450     8.0500    NaN
#
#       embarque   tarifa_real
# 0  Southampton     46.617500
# 1    Cherbourg    458.351619
# 2  Southampton  50957.750000
# 3  Southampton    341.433000
# 4  Southampton     51.761500

# %%
#questão 9)
df[['embarque', 'tarifa']].groupby('embarque').agg(['mean', 'median'])
# Out:
#                    tarifa
#                      mean   median
# embarque
# Cherbourg    12709.345662  37.0042
# Queenstow     2002.842913   7.7500
# Southampton   2015.306986  18.7500

# %%
#questão 10)
df.groupby(['classe']).count()
# Out:
#         id_passageiro  sobreviveu  nome  sexo  idade  irmaos_conjuge  \
# classe
# 1                 216         216   216   216    186             216
# 2                 184         184   184   184    173             184
# 3                 491         491   491   491    355             491
#
#         pais_criancas  passagem  tarifa  cabine  embarque  tarifa_real
# classe
# 1                 216       216     216     176       214          216
# 2                 184       184     184      16       184          184
# 3                 491       491     491      12       491          491

# %%
#questão 11)
df.groupby('classe')
df2 = df.copy()
df.loc[df['sobreviveu'] == 'sim']
df.groupby(df.loc[df['sobreviveu'] == 'sim'])
#['sobreviveu'] == 'sim'].groupby(['classe']).value_counts()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[67], line 3
#       1 #questão 11)
#       2 df.groupby('classe')
# ----> 3 df.groupby(df.loc[df['sobreviveu'] == 'sim'])
#       4 #['sobreviveu'] == 'sim'].groupby(['classe']).value_counts()
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:8399, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    8396     raise TypeError("You have to supply one of 'by' and 'level'")
#    8397 axis = self._get_axis_number(axis)
# -> 8399 return DataFrameGroupBy(
#    8400     obj=self,
#    8401     keys=by,
#    8402     axis=axis,
#    8403     level=level,
#    8404     as_index=as_index,
#    8405     sort=sort,
#    8406     group_keys=group_keys,
#    8407     squeeze=squeeze,
#    8408     observed=observed,
#    8409     dropna=dropna,
#    8410 )
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:959, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     956 if grouper is None:
#     957     from pandas.core.groupby.grouper import get_grouper
# --> 959     grouper, exclusions, obj = get_grouper(
#     960         obj,
#     961         keys,
#     962         axis=axis,
#     963         level=level,
#     964         sort=sort,
#     965         observed=observed,
#     966         mutated=self.mutated,
#     967         dropna=self.dropna,
#     968     )
#     970 self.obj = obj
#     971 self.axis = obj._get_axis_number(axis)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/grouper.py:899, in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     894         in_axis = False
#     896     # create the Grouping
#     897     # allow us to passing the actual Grouping as the gpr
#     898     ping = (
# --> 899         Grouping(
#     900             group_axis,
#     901             gpr,
#     902             obj=obj,
#     903             level=level,
#     904             sort=sort,
#     905             observed=observed,
#     906             in_axis=in_axis,
#     907             dropna=dropna,
#     908         )
#     909         if not isinstance(gpr, Grouping)
#     910         else gpr
#     911     )
#     913     groupings.append(ping)
#     915 if len(groupings) == 0 and len(obj):
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/grouper.py:542, in Grouping.__init__(self, index, grouper, obj, level, sort, observed, in_axis, dropna)
#     540 if getattr(self.grouping_vector, "ndim", 1) != 1:
#     541     t = self.name or str(type(self.grouping_vector))
# --> 542     raise ValueError(f"Grouper for '{t}' not 1-dimensional")
#     544 self.grouping_vector = index.map(self.grouping_vector)
#     546 if not (
#     547     hasattr(self.grouping_vector, "__len__")
#     548     and len(self.grouping_vector) == len(index)
#     549 ):
#
# ValueError: Grouper for '<class 'pandas.core.frame.DataFrame'>' not 1-dimensional

# %%
#questão 12)
df[['sexo', 'sobreviveu']].groupby('sexo').count()
