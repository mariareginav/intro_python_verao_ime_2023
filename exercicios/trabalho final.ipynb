# %% [markdown]
# ## Trabalho Final

# %% [markdown]
# # 1) Quais os retornos logaritmos dos últimos 2 anos da Americanas? É possível observar grandes variações?

# %%
# !pip install yahooquery
# !pip install yahooFinancials
# !pip install yfinance --upgrade --no-cache-dir
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.9/55.9 kB 15.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 kB 35.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.2/113.2 kB 314.1 MB/s eta 0:00:00
# ...

# %%
from yahooquery import Ticker

# %%
# !pip install pandas
# !pip install pandas_datareader
# !pip install --upgrade pandas
# !pip install --upgrade pandas-datareader
# !pip install yahoofinancials
# !pip3 install yfinance==0.2.4
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.4/51.4 kB 2.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: yfinance
#     Found existing installation: yfinance 0.2.9
#     Uninstalling yfinance-0.2.9:
#       Successfully uninstalled yfinance-0.2.9
# ...

# %%
#import numpy as np
#import pandas as pd
#import matplotlib.pyplot as plt
#import pandas_datareader as pdr
#from pandas_datareader import data
#from pandas_datareader import data as pdr

import pandas_datareader as pdr
from pandas_datareader import data
import matplotlib.pyplot as plt
import pandas as pd
import pandas_datareader.data as web
import matplotlib.pyplot as plt


import yahoofinancials as yf
from yahoofinancials import YahooFinancials

# %%
#ticket = "AMER3.SA"

stock = 'AMER3.SA'


start_date = '2021-01-01'
end_date = '2023-01-01'


#dados = data.DataReader(ticker, 'yahoo', start_date, end_date)

#dados = yf.download(stock, start=start_date, end=end_date)
dados = pdr.get_data_yahoo(stock, start=start_date, end=end_date)


#stocks = ['AMER3.SA']
#start = datetime.datetime(2021,1,1)
#end = datetime.datetime(2023,1,1)
#data = yf.download(stocks, start=start, end=end)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[66], line 13
#       7 end_date = '2023-01-01'
#      10 #dados = data.DataReader(ticker, 'yahoo', start_date, end_date)
#      11
#      12 #dados = yf.download(stock, start=start_date, end=end_date)
# ---> 13 dados = pdr.get_data_yahoo(stock, start=start_date, end=end_date)
#      16 #stocks = ['AMER3.SA']
#      17 #start = datetime.datetime(2021,1,1)
#      18 #end = datetime.datetime(2023,1,1)
#      19 #data = yf.download(stocks, start=start, end=end)
#
# File ~/.python/current/lib/python3.10/site-packages/pandas_datareader/data.py:80, in get_data_yahoo(*args, **kwargs)
#      79 def get_data_yahoo(*args, **kwargs):
# ---> 80     return YahooDailyReader(*args, **kwargs).read()
#
# File ~/.python/current/lib/python3.10/site-packages/pandas_datareader/base.py:253, in _DailyBaseReader.read(self)
# ...

# %%
start_date = "2021-01-01"
end_date   = "2023-01-01"

# %%
dados = data.DataReader(ticket, "yahoo", start_date, end_date)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 dados = data.DataReader(ticket, "yahoo", start_date, end_date)
#
# File ~/.python/current/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/.python/current/lib/python3.10/site-packages/pandas_datareader/data.py:379, in DataReader(name, data_source, start, end, retry_count, pause, session, api_key)
#     367     raise NotImplementedError(msg)
#     369 if data_source == "yahoo":
#     370     return YahooDailyReader(
#     371         symbols=name,
#     372         start=start,
#     373         end=end,
#     374         adjust_price=False,
#     375         chunksize=25,
# ...

# %%
from pandas_datareader import data as pdr
import yfinance as yf
yf.pdr_override()
stock = ['AMER3.SA']
from datetime import datetime
data_inicial = datetime(2021,1,1)
data_final = datetime(2023,1,1)
dados = pdr.get_data_yahoo(stock, start=data_inicial, end=data_final)
print(dados)
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                 Open       High        Low      Close  \
#